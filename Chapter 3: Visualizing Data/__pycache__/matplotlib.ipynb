# %%
from matplotlib import pyplot as plt

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

#create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

#add a title
plt.title("Nominal GDP")

#add a label to the y-axis
plt.ylabel("Billions of $")
plt.show()

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gadhi", "West Slide Story"]
num_oscars = [5, 11, 3, 8, 10]

#plot bars with left x-coordinates [0, 1, 2, 3, 4], heights [num_oscars]
plt.bar(movies, num_oscars)

plt.title("My Favourite Movies")
plt.ylabel("# of Academy Awards")

plt.xticks(range(len(movies)), movies)
# Out:
# ([<matplotlib.axis.XTick at 0x1276dfc20>,
#   <matplotlib.axis.XTick at 0x1277f7500>,
#   <matplotlib.axis.XTick at 0x12776e9c0>,
#   <matplotlib.axis.XTick at 0x1278049b0>,
#   <matplotlib.axis.XTick at 0x1278045f0>],
#  [Text(0, 0, 'Annie Hall'),
#   Text(1, 0, 'Ben-Hur'),
#   Text(2, 0, 'Casablanca'),
#   Text(3, 0, 'Gadhi'),
#   Text(4, 0, 'West Slide Story')])
